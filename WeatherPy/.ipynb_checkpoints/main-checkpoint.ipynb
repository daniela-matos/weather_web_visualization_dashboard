# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy

# Import API key
from api_keys import api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())

# Print the city count to confirm sufficient count
print(len(cities))
print(len(countries))
# Out:
# 637
# 637

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create df to store the data
weather = pd.DataFrame({
                        'City': cities, 
                        'Cloudiness': "", 
                        'Country': countries, 
                        'Date': "",
                        'Humidity': "", 
                        'Lat': "", 
                        'Lng': "", 
                        'Max Temp': "", 
                        'Windspeed': ""})

# %%
#Base url to make the API call
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&q='

print('''
-----------------------------
Beginning Data Retrieval
-----------------------------''')

for index, location in weather.iterrows(): 
    
    #Create the query url for the API call
    query_url = base_url + location['City'] + ',' + location['Country'] + '&APPID=' + api_key
    
    #API call
    r = requests.get(query_url)
    
    # get only with status 200 (success status)
    if r.status_code == 200:
        weather.loc[index, 'Cloudiness'] = r.json()['clouds']['all']
        weather.loc[index, 'Date'] = r.json()['dt']
        weather.loc[index, 'Humidity'] = r.json()['main']['humidity']
        weather.loc[index, 'Lat'] = r.json()['coord']['lat']
        weather.loc[index, 'Lng'] = r.json()['coord']['lon']
        weather.loc[index, 'Max Temp'] = r.json()['main']['temp_max']
        weather.loc[index, 'Windspeed'] = r.json()['wind']['speed']
    
    print(f' Processing Record {index} | {location["City"]} ')

print('''
-----------------------------
Data Retrival Complete
-----------------------------''')
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
#  Processing Record 0 | chara
#  Processing Record 1 | mar del plata
#  Processing Record 2 | broome
#  Processing Record 3 | amderma
#  Processing Record 4 | mount gambier
#  Processing Record 5 | rikitea
#  Processing Record 6 | longyearbyen
#  Processing Record 7 | kahului
#  Processing Record 8 | kiunga
#  Processing Record 9 | yellowknife
#  Processing Record 10 | sao francisco
#  Processing Record 11 | acapulco
#  Processing Record 12 | bambous virieux
#  Processing Record 13 | waipawa
#  Processing Record 14 | kaitangata
#  Processing Record 15 | okhotsk
#  Processing Record 16 | tasiilaq
#  Processing Record 17 | khatanga
#  Processing Record 18 | cape town
#  Processing Record 19 | denpasar
#  Processing Record 20 | mys shmidta
#  Processing Record 21 | hofn
#  Processing Record 22 | kapaa
#  Processing Record 23 | vila velha
#  Processing Record 24 | vaini
#  Processing Record 25 | macaravita
#  Processing Record 26 | isangel
#  Processing Record 27 | thompson
#  Processing Record 28 | ribeira grande
#  Processing Record 29 | uribia
#  Processing Record 30 | lebu
#  Processing Record 31 | mastic beach
#  Processing Record 32 | gidole
#  Processing Record 33 | dikson
#  Processing Record 34 | belushya guba
#  Processing Record 35 | varhaug
#  Processing Record 36 | atikokan
#  Processing Record 37 | mataura
#  Processing Record 38 | bredasdorp
#  Processing Record 39 | ponta do sol
#  Processing Record 40 | pevek
#  Processing Record 41 | saint-philippe
#  Processing Record 42 | roald
#  Processing Record 43 | soddy-daisy
#  Processing Record 44 | hami
#  Processing Record 45 | laborie
#  Processing Record 46 | gat
#  Processing Record 47 | manicore
#  Processing Record 48 | tautira
#  Processing Record 49 | chokurdakh
#  Processing Record 50 | rudnichnyy
#  Processing Record 51 | ilinka
#  Processing Record 52 | monte patria
#  Processing Record 53 | oktyabrskoye
#  Processing Record 54 | riyadh
#  Processing Record 55 | port alfred
#  Processing Record 56 | busselton
#  Processing Record 57 | albany
#  Processing Record 58 | qaanaaq
#  Processing Record 59 | rocha
#  Processing Record 60 | beaufort
#  Processing Record 61 | cockburn town
#  Processing Record 62 | vao
#  Processing Record 63 | odweyne
#  Processing Record 64 | atuona
#  Processing Record 65 | whitehorse
#  Processing Record 66 | bainbridge
#  Processing Record 67 | butaritari
#  Processing Record 68 | taolanaro
#  Processing Record 69 | vila
#  Processing Record 70 | arraial do cabo
#  Processing Record 71 | puerto carreno
#  Processing Record 72 | nizhneyansk
#  Processing Record 73 | velikiy ustyug
#  Processing Record 74 | kuala terengganu
#  Processing Record 75 | avarua
#  Processing Record 76 | tuktoyaktuk
#  Processing Record 77 | seminole
#  Processing Record 78 | ushuaia
#  Processing Record 79 | contamana
#  Processing Record 80 | youkounkoun
#  Processing Record 81 | dakoro
#  Processing Record 82 | rabo de peixe
#  Processing Record 83 | bluff
#  Processing Record 84 | seoul
#  Processing Record 85 | fort frances
#  Processing Record 86 | kamenskoye
#  Processing Record 87 | roberval
#  Processing Record 88 | illoqqortoormiut
#  Processing Record 89 | goundam
#  Processing Record 90 | fort saint james
#  Processing Record 91 | shawnee
#  Processing Record 92 | igarka
#  Processing Record 93 | pisco
#  Processing Record 94 | popondetta
#  Processing Record 95 | along
#  Processing Record 96 | kupang
#  Processing Record 97 | punta arenas
#  Processing Record 98 | norman wells
#  Processing Record 99 | puerto ayora
#  Processing Record 100 | luderitz
#  Processing Record 101 | airai
#  Processing Record 102 | saint george
#  Processing Record 103 | upington
#  Processing Record 104 | port elizabeth
#  Processing Record 105 | miles city
#  Processing Record 106 | victoria
#  Processing Record 107 | sitka
#  Processing Record 108 | harper
#  Processing Record 109 | marzuq
#  Processing Record 110 | plouzane
#  Processing Record 111 | vaitupu
#  Processing Record 112 | bud
#  Processing Record 113 | fare
#  Processing Record 114 | mortka
#  Processing Record 115 | tiksi
#  Processing Record 116 | eenhana
#  Processing Record 117 | new norfolk
#  Processing Record 118 | gatesville
#  Processing Record 119 | hermanus
#  Processing Record 120 | saskylakh
#  Processing Record 121 | nikolskoye
#  Processing Record 122 | darhan
#  Processing Record 123 | ashikaga
#  Processing Record 124 | shingu
#  Processing Record 125 | barentsburg
#  Processing Record 126 | gioia del colle
#  Processing Record 127 | saldanha
#  Processing Record 128 | malindi
#  Processing Record 129 | san jose
#  Processing Record 130 | mehamn
#  Processing Record 131 | sentyabrskiy
#  Processing Record 132 | kajaani
#  Processing Record 133 | hobart
#  Processing Record 134 | burla
#  Processing Record 135 | topola
#  Processing Record 136 | ancud
#  Processing Record 137 | scottsboro
#  Processing Record 138 | sola
#  Processing Record 139 | promysla
#  Processing Record 140 | chuy
#  Processing Record 318 | paris
#  Processing Record 319 | parati
#  Processing Record 320 | warqla
#  Processing Record 321 | jining
#  Processing Record 322 | asau
#  Processing Record 323 | vallenar
#  Processing Record 324 | ryotsu
#  Processing Record 325 | wakkanai
#  Processing Record 326 | diamantino
#  Processing Record 327 | katsuura
#  Processing Record 328 | padilla
#  Processing Record 329 | mikhaylovka
#  Processing Record 330 | laguna
#  Processing Record 331 | upernavik
#  Processing Record 332 | qarchi gak
#  Processing Record 333 | jamame
#  Processing Record 334 | lubango
#  Processing Record 335 | arawa
#  Processing Record 336 | belaya
#  Processing Record 337 | cayenne
#  Processing Record 338 | rancho palos verdes
#  Processing Record 339 | sovetskiy
#  Processing Record 340 | yurimaguas
#  Processing Record 341 | brae
#  Processing Record 342 | corrente
#  Processing Record 343 | vardo
#  Processing Record 344 | weligama
#  Processing Record 345 | mahon
#  Processing Record 346 | andenes
#  Processing Record 347 | zaragoza
#  Processing Record 348 | turbat
#  Processing Record 349 | thunder bay
#  Processing Record 350 | carnarvon
#  Processing Record 351 | touros
#  Processing Record 352 | tura
#  Processing Record 353 | buariki
#  Processing Record 354 | muros
#  Processing Record 355 | ishigaki
#  Processing Record 356 | ler
#  Processing Record 357 | nova olimpia
#  Processing Record 358 | batticaloa
#  Processing Record 359 | gombe
#  Processing Record 360 | petropavlovsk-kamchatskiy
#  Processing Record 361 | soe
#  Processing Record 362 | takoradi
#  Processing Record 363 | saint-joseph
#  Processing Record 364 | oberndorf
#  Processing Record 365 | maarianhamina
#  Processing Record 366 | qandala
#  Processing Record 367 | san patricio
#  Processing Record 368 | szczytno
#  Processing Record 369 | helong
#  Processing Record 370 | kutum
#  Processing Record 371 | te anau
#  Processing Record 372 | khonuu
#  Processing Record 373 | bilma
#  Processing Record 374 | raudeberg
#  Processing Record 375 | tosya
#  Processing Record 376 | saint-augustin
#  Processing Record 377 | srednekolymsk
#  Processing Record 378 | matara
#  Processing Record 379 | eureka
#  Processing Record 380 | gulshat
#  Processing Record 381 | anadyr
#  Processing Record 382 | lewistown
#  Processing Record 383 | mitsamiouli
#  Processing Record 384 | zhezkazgan
#  Processing Record 385 | kachiry
#  Processing Record 386 | sarakhs
#  Processing Record 387 | sukumo
#  Processing Record 388 | shiyan
#  Processing Record 389 | binga
#  Processing Record 390 | darab
#  Processing Record 391 | vanimo
#  Processing Record 392 | cartagena
#  Processing Record 393 | cozumel
#  Processing Record 394 | taltal
#  Processing Record 395 | dutlwe
#  Processing Record 396 | wasilla
#  Processing Record 397 | nortelandia
#  Processing Record 398 | muisne
#  Processing Record 399 | port lincoln
#  Processing Record 400 | fort saint john
#  Processing Record 401 | rognan
#  Processing Record 402 | mrirt
#  Processing Record 403 | nanortalik
#  Processing Record 404 | comodoro rivadavia
#  Processing Record 405 | aswan
#  Processing Record 406 | nandyal
#  Processing Record 407 | lompoc
#  Processing Record 590 | kishi
#  Processing Record 591 | pittsfield
#  Processing Record 592 | pathein
#  Processing Record 593 | jiazi
#  Processing Record 594 | tingo maria
#  Processing Record 595 | sabang
#  Processing Record 596 | eregli
#  Processing Record 597 | eydhafushi
#  Processing Record 598 | mareeba
#  Processing Record 599 | allada
#  Processing Record 600 | kirakira
#  Processing Record 601 | rawannawi
#  Processing Record 602 | gloucester
#  Processing Record 603 | mangrol
#  Processing Record 604 | rundu
#  Processing Record 605 | bagdarin
#  Processing Record 606 | sterling
#  Processing Record 607 | russkaya polyana
#  Processing Record 608 | chapais
#  Processing Record 609 | fort nelson
#  Processing Record 610 | malakal
#  Processing Record 611 | el jicaro
#  Processing Record 612 | gunnedah
#  Processing Record 613 | les cayes
#  Processing Record 614 | ituverava
#  Processing Record 615 | bykovo
#  Processing Record 616 | thouars
#  Processing Record 617 | hasaki
#  Processing Record 618 | novovarshavka
#  Processing Record 619 | lucera
#  Processing Record 620 | salinopolis
#  Processing Record 621 | sao joao da barra
#  Processing Record 622 | namibe
#  Processing Record 623 | surt
#  Processing Record 624 | henties bay
#  Processing Record 625 | imbituba
#  Processing Record 626 | kungurtug
#  Processing Record 627 | paoua
#  Processing Record 628 | fortuna
#  Processing Record 629 | buguruslan
#  Processing Record 630 | port hedland
#  Processing Record 631 | isla vista
#  Processing Record 632 | nacala
#  Processing Record 633 | salalah
#  Processing Record 634 | faya
#  Processing Record 635 | vilhena
#  Processing Record 636 | pontianak
#
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %%
# drop rows with Nan values
weather['Max Temp'] = weather['Max Temp'].replace('', np.nan)
weather = weather.dropna()

# %%
#Save dataframe
weather.to_csv("Output/City_Weather_Data.csv", index=False, header=True)

#Preview the dataframe
weather.head(5)
# Out:
#             City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0          chara          0      RU  1578444369       82   56.9  118.26
# 1  mar del plata         66      AR  1578444369       20 -46.43  -67.52
# 2         broome         75      AU  1578444369       88 -17.97  122.23
# 4  mount gambier         89      AU  1578444370       47 -37.83  140.78
# 5        rikitea         11      PF  1578444370       77 -23.12 -134.97
#
#    Max Temp Windspeed
# 0     -5.80      1.01
# 1     66.22     32.61
# 2     82.40     12.75
# 4     75.20     10.29
# 5     77.67     18.86

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather["Lat"], weather["Max Temp"], marker="o", color="darkolivegreen")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature {time.strftime('%m/%d/%Y')}")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output/Latitude_vs_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather["Lat"], weather["Humidity"], marker="o", color="darkolivegreen")
plt.title(f"City Latitude vs. Humidity {time.strftime('%m/%d/%Y')}")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("Output/Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather["Lat"], weather["Cloudiness"], marker="o", color="darkolivegreen")
plt.title(f"City Latitude vs. Cloudiness {time.strftime('%m/%d/%Y')}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("Output/Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather["Lat"], weather["Windspeed"], marker="o", color="darkolivegreen")
plt.title(f"City Latitude vs. Wind Speed {time.strftime('%m/%d/%Y')}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("Output/Latitude_vs_Wind_Speed.png")

# Show plot
plt.show()
